-- %% [markdown]
-- Query the table using time travel

-- %%
SELECT * FROM workspace.streaming_cdc_test.preaggregated_gold TIMESTAMP AS OF current_date() - INTERVAL 1 DAY

-- %%
DESCRIBE HISTORY workspace.streaming_cdc_test.drivers_silver

-- %% [markdown]
-- RESTORE a table as of version 1

-- %%
RESTORE TABLE workspace.streaming_cdc_test.drivers_silver VERSION AS OF 1

-- %% [markdown]
-- Z-ordering by high-cardinality column

-- %%
OPTIMIZE workspace.streaming_cdc_test.drivers_silver ZORDER BY (id)

-- %% [markdown]
-- Simulation of granting permissions, as i have a free version and it does not support Identity and Access Management, i did not test it.

-- %%
CREATE GROUP `innowise`

-- %%
GRANT USAGE ON CATALOG workspace TO innowise;
GRANT USAGE ON SCHEMA workspace.schema_cdc_test TO innowise;
GRANT SELECT ON SCHEMA workspace.schema_cdc_test TO innowise;

-- %%
DENY MODIFY ON SCHEMA workspace.schema_cdc_test TO innowise;
